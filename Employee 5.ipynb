# %% [markdown]
# # Employee Data Analysis

# %% [markdown]
# ## Task 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('DS1_C4_S5_Employee_Data_Practice.xlsx',sheet_name=0)

# %%
data
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 4             1014  Female    Finance              45000   27                4
# ..             ...     ...        ...                ...  ...              ...
# 65            1074  Female         HR              82500   43               13
# 66            1075    Male      Sales              53500   28                5
# 67            1076  Female         HR              57000   29                6
# 68            1077    Male      Sales              66500   33                7
# 69            1078    Male    Finance              92000   45               19
#
# [70 rows x 6 columns]

# %%
plt.figure(figsize=(8,6))
colors = ['blue']
plt.bar(data["Department"],data["Annual Salary ($)"],color=colors)
plt.xlabel("Department")
plt.ylabel("Annual Salary ($)")
plt.title("department wise salary")
plt.show()

# %% [markdown]
# Conclusion - Total Annual sales of employee in each departments is represented as a bar graph.

# %% [markdown]
# ## Task 2

# %%
x=data.groupby(by=['Department','Gender'])['Gender'].count()
x
# Out:
# Department  Gender
# Finance     Female     2
#             Male      11
# HR          Female    11
#             Male       4
# IT          Female    10
#             Male      12
# Sales       Female     4
#             Male      16
# Name: Gender, dtype: int64

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#                    Gender
# Department Gender
# Finance    Female       2
#            Male        11
# HR         Female      11
#            Male         4
# IT         Female      10
#            Male        12
# Sales      Female       4
#            Male        16

# %%
x.plot(x='Department',kind='bar',stacked=False,title='department wise gender',xlabel='Department',ylabel='Gender')
plt.show()

# %% [markdown]
# Conclusion -These are the department wise count of Male and Female employees is represented as a bar graph

# %% [markdown]
# ## Task 3

# %%
new = data[(data["Work_Experience"] == 0) & (data["Department"] == "IT ")]
new
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 7             1017    Male        IT               28000   23                0
# 12            1022    Male        IT               29000   22                0
# 46            1055    Male        IT               27500   22                0
# 47            1056  Female        IT               29000   23                0

# %%
new.groupby(by='Department')['Annual Salary ($)'].mean()
# Out:
# Department
# IT     28100.0
# Name: Annual Salary ($), dtype: float64

# %% [markdown]
# Conclusion - In a IT department the company might offer 28,100$ for a employee with no experience.

# %% [markdown]
# ## Task 4

# %%
filtered=data.groupby(by=['Department'])['Annual Salary ($)'].sum()
filtered
# Out:
# Department
# Finance     790000
# HR          987000
# IT         1282900
# Sales      1089000
# Name: Annual Salary ($), dtype: int64

# %%
pd.DataFrame(filtered)
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
filtered.plot(kind="pie")
plt.pie(filtered,autopct='%.2f%%')
plt.title("Sum of salary in each depatment")
plt.show()

# %% [markdown]
# Conclusion - These are the department wise ratio for the sum of salaries for all employees in each department is represented in a pie chart

# %% [markdown]
# ## Task 5

# %%
data.sort_values("Age",ascending = False)
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 64            1073    Male        IT              170000   50               24
# 29            1039  Female         HR             140000   49               20
# 58            1067  Female        IT               90000   47               17
# 57            1066  Female        IT               88000   46               16
# 69            1078    Male    Finance              92000   45               19
# ..             ...     ...        ...                ...  ...              ...
# 46            1055    Male        IT               27500   22                0
# 38            1047  Female      Sales              28000   22                0
# 17            1027  Female         HR              28000   22                0
# 12            1022    Male        IT               29000   22                0
# 0             1010    Male        IT               27000   22                0
#
# [70 rows x 6 columns]

# %%
plt.hist(data["Age"],bins=5)
plt.xlabel("Age")
plt.ylabel("Employee_Code")
plt.title("Age wise count of employees")
plt.show()

# %% [markdown]
# Conclusion - This is the distribution of employee count by age group in a histogram.

# %% [markdown]
# ## Task 6

# %%
plt.figure(figsize=(15, 8))
plt.scatter(data['Work_Experience'], data['Annual Salary ($)'], color='g', marker='x')
plt.title('Salary Trend based on Employee Experience')
plt.xlabel('Work Experience (years)')
plt.ylabel('Annual Salary ($)')
plt.grid(True)

# %% [markdown]
# Conclusion - This shows the Salary trend based on the employee experience in a Scatter plot.

# %% [markdown]
# ## Task 7

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([data[data['Department'] == 'IT ']['Annual Salary ($)'],
             data[data['Department'] == 'HR']['Annual Salary ($)'],
             data[data['Department'] == 'Finance']['Annual Salary ($)'],
             data[data['Department'] == 'Sales']['Annual Salary ($)']],
            labels=['IT', 'HR', 'Finance', 'Sales'])
plt.title('Department-wise Salary Spread')
plt.xlabel('Department')
plt.ylabel('Annual Salary ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# Conclusion - These are the Department wise Spread of employees salary by using box plot
