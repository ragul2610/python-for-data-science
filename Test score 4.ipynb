# %% [markdown]
# # Test scores of students

# %% [markdown]
# ## Task 1

# %%
import pandas as pd

# %%
data = pd.read_csv("DS1_C4_S4_Test_Scores_Data_Practice.csv")

# %%
data
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
data.isnull().sum()
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 4
# test2                 4
# dtype: int64

# %%
data["gender"].value_counts()
# Out:
# Male      1071
# Female    1052
# Name: gender, dtype: int64

# %%
data["gender"]=data["gender"].fillna("Male")

# %%
a=data["test1"].mean()
a
# Out:
# 54.96195396899953

# %%
data["test1"] = data["test1"].fillna(a)

# %%
b = data["test2"].median()
b
# Out:
# 68.0

# %%
data["test2"] =data["test2"].fillna(b)

# %%
data.isnull().sum()
# Out:
# school               0
# school_setting       0
# school_type          0
# classroom            0
# teaching_method      0
# student_id           0
# gender               0
# tuitionfee_waiver    0
# test1                0
# test2                0
# dtype: int64

# %% [markdown]
# Conclusion - Loaded the data and it is found that the null values in the data are being replaced by mean,median and mode.

# %% [markdown]
# ## Task 2

# %%
data.duplicated(keep=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2128    False
# 2129    False
# 2130    False
# 2131    False
# 2132    False
# Length: 2133, dtype: bool

# %%
df_without_dup = data.drop_duplicates()
df_without_dup
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %% [markdown]
# Conclusion - The data does not have any duplicated rows in it

# %% [markdown]
# ## Task 3

# %%
data["tuitionfee_waiver"] = data["tuitionfee_waiver"].str.replace(r"Does not qualify","No")

# %%
data["tuitionfee_waiver"] = data["tuitionfee_waiver"].str.replace(r"Qualifies for reduced/free","Yes")

# %%
data
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender tuitionfee_waiver  test1  test2
# ...

# %% [markdown]
# Conclusion - In a column named tuitionfee_waiver the values Does not qualify and Qualifies for reduced/freeare replaced as NO and Yes

# %% [markdown]
# ## Task 4

# %%
data2 = data.groupby(["school"])

# %%
data2

# %%
for x,y in data2:
    print(x)
    print(y)
# Out:
# ANKYI
#    school school_setting school_type classroom teaching_method student_id  \
# 0   ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1   ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2   ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3   ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4   ANKYI          Urban  Non-public       6OL        Standard      74LOE
# 5   ANKYI          Urban  Non-public       6OL        Standard      7YZO8
# 6   ANKYI          Urban  Non-public       6OL        Standard      9KMZD
# 7   ANKYI          Urban  Non-public       6OL        Standard      9USQK
# 8   ANKYI          Urban  Non-public       6OL        Standard      CS5QP
# 9   ANKYI          Urban  Non-public       6OL        Standard      D6HT8
# 10  ANKYI          Urban  Non-public       6OL        Standard      DZMKU
# 11  ANKYI          Urban  Non-public       6OL        Standard      FH7B9
# ...

# %%
data.groupby(by='school')['test1'].mean()
# Out:
# school
# ANKYI    61.341463
# CCAAW    64.623853
# CIMBB    65.067568
# CUQAM    53.925234
# DNQDD    54.327869
# FBUMG    62.891304
# GJJHK    53.194915
# GOKXL    50.796875
# GOOBU    38.354190
# IDGFP    75.202128
# KFZMY    41.865385
# KZKKE    37.261261
# LAYPA    62.035088
# OJOBU    56.197531
# QOQTS    52.543369
# UAGPU    62.390805
# UKPGS    78.453125
# UUUQX    67.106690
# VHDHF    52.666667
# VKWQH    52.060000
# VVTVA    36.122473
# ZMNYA    68.130435
# ZOWMK    41.572650
# Name: test1, dtype: float64

# %% [raw]
# Conclusion - The average of test1 scores of students at each scools is displayed.The school with highest average test1 score is 'UKPGS'

# %% [markdown]
# ## Task 5

# %%
piv = pd.pivot_table(data,index=['school'],values=['test2'],aggfunc='sum')
piv
# Out:
#           test2
# school
# ANKYI    2927.0
# CCAAW    8514.0
# CIMBB    5694.0
# CUQAM    7015.0
# DNQDD    8121.0
# FBUMG    3616.0
# GJJHK    7673.0
# GOKXL    4157.0
# GOOBU    7862.0
# IDGFP    8199.0
# KFZMY    2838.0
# KZKKE    5319.0
# LAYPA    4188.0
# OJOBU    5493.0
# QOQTS    9636.0
# UAGPU    6253.0
# UKPGS   11649.0
# UUUQX    6658.0
# VHDHF    3409.0
# VKWQH    6482.0
# VVTVA    5628.0
# ZMNYA    5631.0
# ZOWMK    6190.0

# %%
sort = piv.sort_values('test2', ascending=False)

# %%
sort
# Out:
#           test2
# school
# UKPGS   11649.0
# QOQTS    9636.0
# CCAAW    8514.0
# IDGFP    8199.0
# DNQDD    8121.0
# GOOBU    7862.0
# GJJHK    7673.0
# CUQAM    7015.0
# UUUQX    6658.0
# VKWQH    6482.0
# UAGPU    6253.0
# ZOWMK    6190.0
# CIMBB    5694.0
# ZMNYA    5631.0
# VVTVA    5628.0
# OJOBU    5493.0
# KZKKE    5319.0
# LAYPA    4188.0
# GOKXL    4157.0
# FBUMG    3616.0
# VHDHF    3409.0
# ANKYI    2927.0
# KFZMY    2838.0

# %%
sort.head()
# Out:
#           test2
# school
# UKPGS   11649.0
# QOQTS    9636.0
# CCAAW    8514.0
# IDGFP    8199.0
# DNQDD    8121.0

# %% [markdown]
# Conclusion - The top 5 schools which have highest test2 scores .

# %% [markdown]
# ## Task 6

# %%
sco=(data.school == "FBUMG") & (data.classroom =="5LQ") & (data.test2 > 80.0)

# %%
scolorship=pd.DataFrame(sco)

# %%
scolorship
# Out:
#           0
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 2128  False
# 2129  False
# 2130  False
# 2131  False
# 2132  False
#
# [2133 rows x 1 columns]

# %%
data=pd.concat([data,sco],axis=1)

# %%
data
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender tuitionfee_waiver  test1  test2      0
# ...

# %% [markdown]
# Conclusion - Added a new column and assigned scholorship for the filter school == "FBUMG",classroom =="5LQ" and test2 > 80.0.

# %% [markdown]
# ## Task 7

# %%
pd.crosstab(data.school_setting,data.teaching_method)
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %% [markdown]
# Conclusion - The count of each type of teaching_method in different school_settings is showed

# %% [markdown]
# ## Task 8

# %%
data.groupby(by=['school_setting','gender'])['school_setting'].count()
# Out:
# school_setting  gender
# Rural           Female    228
#                 Male      282
# Suburban        Female    368
#                 Male      349
# Urban           Female    456
#                 Male      450
# Name: school_setting, dtype: int64

# %% [markdown]
# Conclusion - The count of Male and Female in different school_settings is displayed.

# %% [markdown]
# ## Task 9

# %%
piv2 = pd.pivot_table(data,index=['school_setting','gender'],values=['test2'],aggfunc='mean')

# %%
piv2
# Out:
#                            test2
# school_setting gender
# Rural          Female  63.991228
#                Male    64.092199
# Suburban       Female  76.027174
#                Male    75.991404
# Urban          Female  61.179825
#                Male    62.424444

# %% [markdown]
# Conclusion - The average of test2 scores of Male and Female in different school-settings is shown.
