# %% [markdown]
# # Bank Loan Prediction

# %% [markdown]
# ## Task 1

# %%
import pandas as pd

# %%
data = pd.read_csv('DS1_C4_S3_Loan_Data_Challenge.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# Conclusion - Loaded the data in dataframe and done some basic functions.

# %% [markdown]
# ## Task 2

# %%
data[(data["Gender"] == "Female") & (data["Self_Employed"] == "Yes") & (data["ApplicantIncome"] > 4000)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# Conclusion - sorted the data by female who are self employed and annual income greater than 4000

# %% [markdown]
# ## Task 3

# %%
gra_male=data[(data["Gender"] == "Male") & (data["Education"] == "Graduate") & (data["Loan_Status"] == "Y")]

# %%
gra_male
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
len(gra_male)
# Out:
# 279

# %% [markdown]
# Conclusion - Found the male who are graduate and have loan status "Y".and found thier count.

# %% [markdown]
# ## Task 4

# %%
data[(data["Loan_Status"] == "Y") & (data["Property_Area"] == "Rural") & (data["Dependents"] >= "3")]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# Conclusion - Found who lives in rural with dependents more than 3 and loan status is "Y".

# %% [markdown]
# ## Task 5

# %%
data["Education"].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
data["Property_Area"].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %% [markdown]
# Kim is graduate and lives in urban...according to previous records of graduate and urban kim will get loan.

# %% [markdown]
# ## Task 6

# %%
data1=data[(data["Married"] == "No") & (data["Property_Area"] != "Urban") & (data["Self_Employed"] == "Yes") & (data["Loan_Status"] == "N")]

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0         106               360
# 107             7333                0.0         120               360
# 286             2600             1717.0          99               300
# 404             7441                0.0         194               360
# ...

# %%
gender_counts = data1['Gender'].value_counts()

# %%
gender_counts
# Out:
# Female    4
# Male      3
# Name: Gender, dtype: int64

# %% [markdown]
# Conclusion - Customers who are not married lives in urban,self employed and loan status  "N" is displayed..and the counts of male and female is found.

# %% [markdown]
# ## Task 7

# %%
Rural=data[(data.ApplicantIncome) & (data["Property_Area"] == "Rural")]

# %%
Rural
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 23   LP001050   Male     Yes          2  Not Graduate            No
# 62   LP001207   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 593  LP002936   Male     Yes          0      Graduate            No
# 595  LP002940   Male      No          0  Not Graduate            No
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 598  LP002945   Male     Yes          0      Graduate           Yes
# 607  LP002964   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0         128               360
# ...

# %%
Rural["ApplicantIncome"].mean()
# Out:
# 5255.9655172413795

# %%
Urban=data[(data.ApplicantIncome) & (data["Property_Area"] == "Urban")]

# %%
Urban
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 12   LP001028   Male     Yes          2      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 575  LP002868   Male     Yes          2      Graduate            No
# 577  LP002874   Male      No          0      Graduate            No
# 586  LP002916   Male     Yes          0      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
Urban["ApplicantIncome"].mean()
# Out:
# 5830.04255319149

# %%
Semiurban=data[(data.ApplicantIncome) & (data["Property_Area"] == "Semiurban")]

# %%
Semiurban
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 9    LP001020    Male     Yes          1      Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           Yes
# 26   LP001068    Male     Yes          0      Graduate            No
# 37   LP001112  Female     Yes          0      Graduate            No
# 43   LP001131    Male     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 576  LP002872    Male     Yes          0      Graduate            No
# 587  LP002917  Female      No          0  Not Graduate            No
# 592  LP002933    Male      No         3+      Graduate           Yes
# 597  LP002943    Male      No          1      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Semiurban["ApplicantIncome"].mean()
# Out:
# 5613.069565217392

# %% [markdown]
# Conclusion - The average income on rural,urban and semi-urban is found to be 5255.9,5830.0 and 5613.0

# %% [markdown]
# ## Task 8

# %%
urb=data[(data["ApplicantIncome"] > 4000) & (data["Property_Area"] != "Urban") & (data["Loan_Status"] == "N") & (data["CoapplicantIncome"] > 1000)]

# %%
urb
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %%
urb['Loan_Status'] = urb['Loan_Status'].replace("N","Y")
# Out:
# C:\Users\Ragul\AppData\Local\Temp\ipykernel_18800\1096989659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urb['Loan_Status'] = urb['Loan_Status'].replace("N","Y")

# %%
urb
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %% [markdown]
# Conclusion - Customers who have property in rural and semi-urban and income greater than 4000 and co applicangt income greater then 1000 and loan status is "No"..updated the loan status as "Yes" too those customers.

# %% [markdown]
# ## Task 9

# %%
more_than_3=data[(data["Property_Area"] != "Urban") & (data["Loan_Status"] == "Y") & (data["Dependents"] > "3")]

# %%
more_than_3
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 109  LP001384    Male     Yes         3+  Not Graduate            No
# 126  LP001448    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 215  LP001720    Male     Yes         3+  Not Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 321  LP002053    Male     Yes         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 343  LP002126    Male     Yes         3+  Not Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 359  LP002160    Male     Yes         3+      Graduate            No
# ...

# %%
more_than_3["ApplicantIncome"].mean()
# Out:
# 7861.28

# %%
len(more_than_3)
# Out:
# 25

# %% [markdown]
# Conclusion - Customers who have 3+ dependents who lives in urban and loan status is "Y" is found.the average income of those is found.

# %% [markdown]
# ## Task 10

# %%
A=data[(data["Property_Area"] != "Urban") & (data["Dependents"] > "3")]

# %%
A
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 78   LP001263    Male     Yes         3+      Graduate            No
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 109  LP001384    Male     Yes         3+  Not Graduate            No
# 126  LP001448    Male     Yes         3+      Graduate            No
# 135  LP001488    Male     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 172  LP001586    Male     Yes         3+  Not Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 211  LP001711    Male     Yes         3+      Graduate            No
# ...

# %%
A["ApplicantIncome"].mean()
# Out:
# 8811.631578947368

# %%
df=A[(A["ApplicantIncome"] > 8811.63)]

# %%
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 34   LP001100   Male      No         3+  Graduate            No
# 126  LP001448   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 324  LP002065   Male     Yes         3+  Graduate            No
# 390  LP002255   Male      No         3+  Graduate            No
# 391  LP002262   Male     Yes         3+  Graduate            No
# 409  LP002317   Male     Yes         3+  Graduate            No
# 557  LP002795   Male     Yes         3+  Graduate           Yes
# 592  LP002933   Male      No         3+  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 34             12500             3000.0         320               360
# 126            23803                0.0         370               360
# 155            39999                0.0         600               180
# ...

# %%
avg_inc=df[(df["Loan_Status"] == "Y")]

# %%
avg_inc
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 126  LP001448   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 324  LP002065   Male     Yes         3+  Graduate            No
# 390  LP002255   Male      No         3+  Graduate            No
# 391  LP002262   Male     Yes         3+  Graduate            No
# 557  LP002795   Male     Yes         3+  Graduate           Yes
# 592  LP002933   Male      No         3+  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 126            23803                0.0         370               360
# 155            39999                0.0         600               180
# 324            15000                0.0         300               360
# 390             9167                0.0         185               360
# 391             9504                0.0         275               360
# ...

# %%
df["ApplicantIncome"].mean()
# Out:
# 23385.444444444445

# %% [markdown]
# Conclusion - Customers who live in rural and semi-urban with 3+ dependents and income greater than average income of customer who lives in urban.From these for approving loans bank sees applicant income,loan amount and loan amount term mainly.applying loan status to "YES" to all who live in rural and semi-urban with 3+ dependents and income greater than average income of customer who lives in urban.
