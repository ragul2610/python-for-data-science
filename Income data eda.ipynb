# %% [markdown]
# ### Task 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tabulate import tabulate

# %%
df = pd.read_excel("DS1_C5_S2_Income_Data_Challenge.xlsx")

# %%
df
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'WorkClass', 'Education', 'Education_Num', 'Marital_Status',
#        'Occupation', 'Relationship', 'Gender', 'Hours_Per_Week',
#        'Native_Country', 'Income_Bracket'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age               0
# WorkClass         0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Gender            0
# Hours_Per_Week    0
# Native_Country    0
# Income_Bracket    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Education       32561 non-null  object
#  3   Education_Num   32561 non-null  int64
#  4   Marital_Status  32561 non-null  object
#  5   Occupation      32561 non-null  object
#  6   Relationship    32561 non-null  object
#  7   Gender          32561 non-null  object
#  8   Hours_Per_Week  32561 non-null  int64
#  9   Native_Country  32561 non-null  object
#  10  Income_Bracket  32561 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 2.7+ MB

# %%
df.head()
# Out:
#    Age   WorkClass   Education  Education_Num       Marital_Status  \
# 0   39   State-gov   Bachelors             13        Never-married
# 1   50    Self-emp   Bachelors             13   Married-civ-spouse
# 2   38     Private     HS-grad              9             Divorced
# 3   53     Private        11th              7   Married-civ-spouse
# 4   28     Private   Bachelors             13   Married-civ-spouse
#
#            Occupation    Relationship   Gender  Hours_Per_Week  \
# 0        Adm-clerical   Not-in-family     Male              40
# 1     Exec-managerial         Husband     Male              13
# 2   Handlers-cleaners   Not-in-family     Male              40
# 3   Handlers-cleaners         Husband     Male              40
# 4      Prof-specialty            Wife   Female              40
#
#    Native_Country Income_Bracket
# 0   United-States          <=50K
# 1   United-States          <=50K
# 2   United-States          <=50K
# 3   United-States          <=50K
# ...

# %%
df.tail()
# Out:
#        Age  WorkClass    Education  Education_Num       Marital_Status  \
# 32556   27    Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40    Private      HS-grad              9   Married-civ-spouse
# 32558   58    Private      HS-grad              9              Widowed
# 32559   22    Private      HS-grad              9        Never-married
# 32560   52   Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation Relationship   Gender  Hours_Per_Week  \
# 32556        Tech-support         Wife   Female              38
# 32557   Machine-op-inspct      Husband     Male              40
# 32558        Adm-clerical    Unmarried   Female              40
# 32559        Adm-clerical    Own-child     Male              20
# 32560     Exec-managerial         Wife   Female              40
#
#        Native_Country Income_Bracket
# 32556   United-States          <=50K
# 32557   United-States           >50K
# 32558   United-States          <=50K
# ...

# %%
# separating  numeric and categorical columns
numeric_columns = []
categorical_columns = []

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        numeric_columns.append(column)
    else:
        categorical_columns.append(column)

table = [numeric_columns, categorical_columns]
print(tabulate({"numerical":numeric_columns,
                "categorical": categorical_columns}, headers = ["numerical", "categorical"]))
# Out:
# numerical       categorical
# --------------  --------------
# Age             WorkClass
# Education_Num   Education
# Hours_Per_Week  Marital_Status
#                 Occupation
#                 Relationship
#                 Gender
#                 Native_Country
#                 Income_Bracket

# %% [markdown]
# # Interpretation -separated the Columns into Numerical and Categorical , stored them in two separate list .

# %% [markdown]
# # Perform Bi-variant and Multi-variant for Categorical columns

# %% [markdown]
# #                        Gender wise workclass of the employees

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "WorkClass", data = df)
plt.show()

# %% [markdown]
# # Interpretation - This is the Gender wise workclass of the employees .

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Education", data = df)
plt.show()

# %% [markdown]
# # Interpretation - This is the Gender wise education of the employees .

# %% [markdown]
# # Gender wise Marital_Status of the employees

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Marital_Status", data = df)
plt.show()

# %% [markdown]
# # Interpretation - This is the gender wise Marital status of the employees .

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Occupation", data = df)
plt.show()

# %% [markdown]
# # Interpretation - This is the Gender wise occupaton the employees .

# %% [markdown]
# ## Gender wise Relationship of the employees

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Relationship", data = df)
plt.show()

# %% [markdown]
# Interpretation -  Here i have displayed the Gender wsie Relationship of the employees in their families .

# %%
fig, ax = plt.subplots(figsize = (20, 15))
sns.countplot(x = "Gender", hue = "Native_Country", data = df)
plt.show()

# %% [markdown]
# ##  Gender wise Income Bracket of the employees

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "Gender", hue = "Income_Bracket", data = df)
plt.show()

# %% [markdown]
# # Interpretatuion -The Gender wise Income_brackets of the employees .

# %% [markdown]
# # Bi-variant and Multi-variant analysis for all the numerical columns

# %% [markdown]
# ## Gender wise Age of the employees

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["Age"], hue = df["Gender"], ax = ax[0])
sns.boxplot(y = df["Age"], x = df["Gender"], ax = ax[1])
plt.show()

# %% [markdown]
# ## Gender wise Education Num of the employees

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
sns.histplot(x = df["Education_Num"], hue = df["Gender"], ax = ax[0])
sns.boxplot(y = df["Education_Num"], x = df["Gender"], ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation - This is the Gender wise Education Num of the employees .

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 10))
sns.histplot(x = df["Hours_Per_Week"], hue = df["Gender"], ax = ax[0])
sns.boxplot(y = df["Hours_Per_Week"], x = df["Gender"], ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation - This is the Gender wise Hours-per-week of the employees  .
