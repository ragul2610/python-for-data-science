# %% [markdown]
# ### Task 1

# %%
import pandas as pd
import mysql.connector as sql

# %%
data = pd.read_csv("DS1_C4_S6_House_Prices_Data_Challenge.csv")

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
db = sql.connect(host='localhost',user='root',password='Ramalingam123')

# %%
mycursor  = db.cursor()

# %%
mycursor.execute("create database Housing")

# %%
data1 = data[(data["LotArea"]>=6000) & (data["LotConfig"]=="Corner")]

# %%
data1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1413  1414          20       RL         88.0    10994   Pave   NaN      IR1
# 1420  1421          60       RL         90.0    11700   Pave   NaN      Reg
# 1428  1429          30       RM         60.0     7200   Pave   NaN      Reg
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
#
# ...

# %%
from sqlalchemy import create_engine

# %%
mycursor.execute("use Housing")

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host='localhost', db='Housing', user='root', pw='Ramalingam123'))

data1.to_sql('plot area 6000 and corner plot', engine, index=False, if_exists='replace')
# Out:
# 241

# %% [markdown]
# Conclusion - Created a database and then performed some task and then at last i have pushed the dataframe into mysql.

# %% [markdown]
# ### Task 2

# %%
data2 = data[(data["BldgType"]=="1Fam") & (data["HouseStyle"]=="1Story") & (data["Street"]=="Pave") & (data["Alley"]=="Pave")]

# %%
data2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 164    165          40       RM         40.0     5400   Pave  Pave      Reg
# 281    282          20       FV         60.0     7200   Pave  Pave      Reg
# 381    382          20       FV         60.0     7200   Pave  Pave      Reg
# 525    526          20       FV         62.0     7500   Pave  Pave      Reg
# 836    837          30       RM         90.0     8100   Pave  Pave      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 164          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 281          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 381          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 525          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ...

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host='localhost', db='Housing', user='root', pw='Ramalingam123'))

data2.to_sql('house with 1story and 1family', engine, index=False, if_exists='replace')
# Out:
# 6

# %% [markdown]
# Conclusion - Created a dataframe which consist of 1family and 1 story and the streets not in mountains or valleys and push the dataframe into sql.

# %% [markdown]
# ### Task 3

# %%
data3 = data[(data["LotArea"]<=5000) & (data["OverallQual"]>3) & (data["OverallQual"]<6) & (data["1stFlrSF"]<=1000) 
             & (data["BedroomAbvGr"]<=3) & (data["GarageArea"]<400)]

# %%
data3
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 68      69          30       RM         47.0     4608   Pave   NaN      Reg
# 75      76         180       RM         21.0     1596   Pave   NaN      Reg
# 127    128          45       RM         55.0     4388   Pave   NaN      IR1
# 204    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 225    226         160       RM         21.0     1680   Pave   NaN      Reg
# 241    242          30       RM         40.0     3880   Pave   NaN      Reg
# 242    243          50       RM         63.0     5000   Pave   NaN      Reg
# 325    326          45       RM         50.0     5000   Pave   NaN      Reg
# 344    345         160       RM         36.0     2592   Pave   NaN      Reg
# 434    435         180       RM         21.0     1890   Pave   NaN      Reg
# ...

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host='localhost', db='Housing', user='root', pw='Ramalingam123'))

data3.to_sql('Compact houses', engine, index=False, if_exists='replace')
# Out:
# C:\Users\Ragul\AppData\Local\Temp\ipykernel_9620\66430259.py:4: UserWarning: The provided table name 'Compact houses' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   data3.to_sql('Compact houses', engine, index=False, if_exists='replace')
# 28

# %% [markdown]
# Conclusion - The compact houses is found by the filters and then pushed it into mysql.

# %% [markdown]
# ### Task 4

# %%
data4 = data[(data["BedroomAbvGr"]==3) & (data["Exterior1st"]=="CemntBd") & (data["TotalBsmtSF"]!=0)]

# %%
data4
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 108    109          50       RM         85.0     8500   Pave   NaN      Reg
# 196    197          20       RL         79.0     9416   Pave   NaN      Reg
# 261    262          60       RL         69.0     9588   Pave   NaN      IR1
# 278    279          20       RL        107.0    14450   Pave   NaN      Reg
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 305    306          20       RL         80.0    10386   Pave   NaN      Reg
# 344    345         160       RM         36.0     2592   Pave   NaN      Reg
# 357    358         120       RM         44.0     4224   Pave   NaN      Reg
# 421    422          20       RL          NaN    16635   Pave   NaN      IR1
# 490    491         160       RM          NaN     2665   Pave   NaN      Reg
# ...

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host='localhost', db='Housing', user='root', pw='Ramalingam123'))

data4.to_sql('3bedroom and basement', engine, index=False, if_exists='replace')
# Out:
# 34

# %% [markdown]
# Conclusion - The houses with 3 bedrooms , a basement and cement exterior is found and pushed the data into SQL

# %% [markdown]
# ### Task 5

# %%
data5 = data[(data["GarageArea"]>=500)]

# %%
data5
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
# ...

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host='localhost', db='Housing', user='root', pw='Ramalingam123'))

data5.to_sql('Garage area', engine, index=False, if_exists='replace')
# Out:
# C:\Users\Ragul\AppData\Local\Temp\ipykernel_9620\2161601982.py:4: UserWarning: The provided table name 'Garage area' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   data5.to_sql('Garage area', engine, index=False, if_exists='replace')
# 635

# %% [markdown]
# Conclusion - The Garage space is greater than 500sq feet and then pushed the data into SQL
